# %%
import pandas as pd
from io import StringIO

# Create the CSV data
data = """Student_ID,Name,Age,Course,Marks,Attendance_Percentage,City
1001,Aarav Sharma,19,Data Science,87.0,91.0,Srinagar
1002,Zoya Khan,20,AI,92.0,95.0,Delhi
1003,Rohan Mehta,18,Computer Science,76.0,82.0,Mumbai
1004,Ananya Singh,21,Data Science,81.0,88.0,Srinagar
1005,Kabir Ali,19,AI,69.0,76.0,Lucknow
1006,Ishita Gupta,20,Computer Science,88.0,93.0,Bengaluru
1007,Aditya Verma,22,Data Science,95.0,97.0,Pune
1008,Sara Ahmed,19,AI,73.0,,Hyderabad
1009,Arjun Nair,18,Computer Science,84.0,86.0,Kochi
1010,Mehak Bhat,21,Data Science,79.0,90.0,Srinagar
1011,Vivaan Kapoor,20,AI,91.0,94.0,Jaipur
1012,Aisha Mir,19,Computer Science,68.0,72.0,Delhi
1013,Rahul Das,23,Data Science,72.0,81.0,Kolkata
1014,Sana Malik,18,AI,89.0,92.0,
1015,Karan Joshi,20,Computer Science,77.0,85.0,Chandigarh
1016,Hiba Sheikh,21,Data Science,94.0,96.0,Srinagar
1017,Dev Patel,19,AI,86.0,89.0,Ahmedabad
1018,Manya Rao,22,Computer Science,70.0,74.0,Bengaluru
1019,Yusuf Dar,20,Data Science,,87.0,Srinagar
1020,Priya Menon,21,AI,90.0,91.0,Chennai
1021,Aman Kumar,18,Computer Science,74.0,78.0,Delhi
1022,Alina Shah,19,Data Science,96.0,98.0,Srinagar
1023,Nikhil Sood,22,AI,78.0,83.0,Pune
1024,Maryam Khan,20,Computer Science,85.0,88.0,Hyderabad
1025,Reyansh Jain,21,Data Science,80.0,84.0,Kolkata"""

# Load data into Pandas DataFrame
df = pd.read_csv(StringIO(data))

# Display dataset
print("========== DATASET ==========")
print(df)

# First 5 rows
print("\n========== FIRST 5 ROWS ==========")
print(df.head())

# Last 5 rows
print("\n========== LAST 5 ROWS ==========")
print(df.tail())

# Random 5 rows
print("\n========== RANDOM 5 ROWS ==========")
print(df.sample(5))

# Shape
print("\n========== DATASET SHAPE ==========")
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
print("Shape:", df.shape)

# Columns
print("\n========== COLUMNS ==========")
print(df.columns)

# Index
print("\n========== INDEX ==========")
print(df.index)

# Data types
print("\n========== DATA TYPES ==========")
print(df.dtypes)

# Dataset information
print("\n========== DATASET INFORMATION ==========")
df.info()

# Descriptive statistics
print("\n========== DESCRIPTIVE STATISTICS ==========")
print(df.describe())

# Statistics for all columns
print("\n========== ALL COLUMN STATISTICS ==========")
print(df.describe(include="all"))

# Missing values
print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())

# Total missing values
print("\n========== TOTAL MISSING VALUES ==========")
print("Total missing values:", df.isnull().sum().sum())

# Basic observations
print("\n========== BASIC OBSERVATIONS ==========")
print("Number of students:", len(df))
print("Number of features:", len(df.columns))

print("\nAvailable features:")
for column in df.columns:
    print("-", column)

print("\nMissing values by column:")
for column in df.columns:
    print(column, ":", df[column].isnull().sum())

print("\n========== CONCLUSION ==========")
print("The dataset contains", df.shape[0], "students and", df.shape[1], "features.")
print("The dataset contains both numerical and categorical data.")
print("There are", df.isnull().sum().sum(), "missing values in total.")
print("The dataset was successfully explored using Python and Pandas.")
# Out:
# ========== DATASET ==========
#     Student_ID           Name  Age            Course  Marks  \
# 0         1001   Aarav Sharma   19      Data Science   87.0
# 1         1002      Zoya Khan   20                AI   92.0
# 2         1003    Rohan Mehta   18  Computer Science   76.0
# 3         1004   Ananya Singh   21      Data Science   81.0
# 4         1005      Kabir Ali   19                AI   69.0
# 5         1006   Ishita Gupta   20  Computer Science   88.0
# 6         1007   Aditya Verma   22      Data Science   95.0
# 7         1008     Sara Ahmed   19                AI   73.0
# 8         1009     Arjun Nair   18  Computer Science   84.0
# 9         1010     Mehak Bhat   21      Data Science   79.0
# 10        1011  Vivaan Kapoor   20                AI   91.0
# 11        1012      Aisha Mir   19  Computer Science   68.0
# 12        1013      Rahul Das   23      Data Science   72.0
# 13        1014     Sana Malik   18                AI   89.0
# ...
